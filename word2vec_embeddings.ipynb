# %%
import time 
import tensorflow as tf
import numpy as np
import utils
from urllib.request import urlretrieve
from os.path import isfile , isdir
from tqdm import tqdm
import zipfile

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
  urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [00:43, 718kB/s]

# %%
words=utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %%
vocab_to_int,int_to_vocab=utils.create_lookup_tables(words)

# %%
int_words=[vocab_to_int[word] for word in words]

# %%
# Out:
# [5233,
#  3080,
#  11,
#  5,
#  194,
#  1,
#  3133,
#  45,
#  58,
#  155,
#  127,
#  741,
#  476,
#  10571,
#  133,
#  0,
#  27349,
#  1,
#  0,
#  102,
#  854,
#  2,
#  0,
#  15067,
#  58112,
#  1,
#  0,
#  150,
#  854,
#  3580]

# %%
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]

# %%
len(train_words)
# Out:
# 4627183

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %%
n_vocab=len(int_to_vocab)
n_embedding=200
with train_graph.as_default():
  embedding=tf.Variable(tf.random_uniform((n_vocab,n_embedding),-1,1))
  embed=tf.nn.embedding_lookup(embedding,inputs)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed,
                                      n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/nn_impl.py:1444: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/array_grad.py:425: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))
# Out:
# WARNING:tensorflow:From <ipython-input-48-2aa168c49a56>:13: calling reduce_sum_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
# !mkdir checkpoints

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6637 0.0389 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6032 0.0296 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5049 0.0295 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5857 0.0296 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5213 0.0296 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5429 0.0295 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5603 0.0295 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5253 0.0297 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.5120 0.0297 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4336 0.0297 sec/batch
# Nearest to known: helping, serene, mimic, adds, scent, heenan, adler, khattab,
# Nearest to during: fugees, milton, convoked, autonomic, exclaims, heligoland, battlements, monologues,
# Nearest to see: honeys, circulates, bakker, ravage, crenshaw, assiniboine, blastocyst, capone,
# Nearest to zero: icy, underlying, automate, underpinning, demerara, ishbaal, rejection, kora,
# Nearest to when: hulk, emendations, saturated, lustrous, consolidated, poles, laing, slobodan,
# Nearest to most: syllable, ottawa, kahan, preregular, trademarked, whittier, khariboli, matador,
# Nearest to about: necessary, lov, scooters, fed, unchangeable, mrsa, yucat, deepwater,
# Nearest to all: cable, futile, aerobics, securities, kinds, camping, reinsurance, constricted,
# Nearest to san: synthetic, sydney, unresponsive, egolessness, salom, presumes, saga, including,
# Nearest to older: capensis, isolating, alster, sauk, radium, powerplant, erfurt, oshkosh,
# Nearest to heavy: observers, fuses, singaporean, shared, dicke, cyprinus, annular, porridge,
# Nearest to road: oecd, sepoy, juliana, cocker, whistles, crevasse, codon, banteng,
# Nearest to primarily: tirpitz, slovenia, settings, conciliatory, wuxia, pbsuccess, sponsor, aimed,
# Nearest to animals: runic, gluing, soloing, roux, alice, convolution, dinger, ndische,
# Nearest to channel: beery, sukhum, lysander, signified, declared, islet, lie, busan,
# Nearest to account: polytheism, exploitative, kruskal, objectification, africans, baryonic, everlast, incompetent,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4858 0.0311 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3854 0.0296 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3362 0.0296 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2693 0.0295 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1829 0.0299 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1737 0.0294 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0874 0.0295 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0421 0.0296 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0345 0.0293 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 5.0020 0.0295 sec/batch
# Nearest to known: helping, including, mimic, adds, diplomatic, scent, depends, tendency,
# Nearest to during: fugees, milton, choose, scientific, claim, universally, monologues, talks,
# Nearest to see: reality, crenshaw, circulates, ravage, honeys, assiniboine, c, friction,
# Nearest to zero: icy, underlying, historical, usual, automate, viewers, demerara, underpinning,
# Nearest to when: consolidated, hulk, poles, saturated, lustrous, emendations, symbols, flip,
# Nearest to most: ottawa, syllable, computer, or, dominant, grotesque, matador, won,
# Nearest to about: necessary, lov, fed, unchangeable, which, concerned, yucat, anniversary,
# Nearest to all: kinds, producing, futile, trading, cable, securities, where, unknown,
# Nearest to san: synthetic, sydney, including, be, campus, st, presumes, saga,
# Nearest to older: isolating, is, radium, sauk, powerplant, cipher, capensis, complexity,
# Nearest to heavy: observers, shared, element, battle, annular, fuses, spectrometer, singaporean,
# Nearest to road: oecd, sepoy, whistles, cocker, banteng, single, proved, juliana,
# Nearest to primarily: settings, slovenia, aimed, greeks, current, tirpitz, wuxia, sponsor,
# Nearest to animals: lines, roux, zapatistas, runic, presumably, soloing, gluing, alice,
# Nearest to channel: declared, sukhum, beery, lysander, difficulties, lie, contains, assign,
# Nearest to account: polytheism, asian, kruskal, objectification, exploitative, pbs, africans, baryonic,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9170 0.0307 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9027 0.0296 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8692 0.0294 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8815 0.0296 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.7932 0.0295 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8309 0.0297 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7829 0.0296 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7995 0.0296 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7733 0.0295 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7709 0.0297 sec/batch
# Nearest to known: helping, adds, kepler, score, scent, serene, mimic, including,
# Nearest to during: milton, fugees, convoked, choose, monologues, claim, scientific, autonomic,
# Nearest to see: reality, circulates, ravage, assiniboine, crenshaw, categorised, friction, honeys,
# Nearest to zero: icy, demerara, automate, total, otto, ipa, viewers, impressive,
# Nearest to when: hulk, saturated, emendations, lustrous, consolidated, poles, slobodan, symbols,
# Nearest to most: syllable, ottawa, computer, dominant, trademarked, kahan, or, swing,
# Nearest to about: necessary, lov, fed, anniversary, concerned, unchangeable, mare, which,
# Nearest to all: kinds, trading, securities, cable, futile, producing, jets, camping,
# Nearest to san: synthetic, sydney, campus, st, presumes, including, caucasus, completing,
# Nearest to older: isolating, radium, is, powerplant, sauk, cipher, capensis, patients,
# Nearest to heavy: observers, fuses, shared, element, singaporean, casualties, dicke, annular,
# Nearest to road: oecd, whistles, sepoy, cocker, proved, banteng, synthetic, gladio,
# Nearest to primarily: settings, slovenia, aimed, bologna, current, tirpitz, greeks, leo,
# Nearest to animals: roux, lines, zapatistas, runic, alice, presumably, leather, gluing,
# Nearest to channel: sukhum, declared, beery, lie, lysander, signified, assign, difficulties,
# Nearest to account: polytheism, africans, lesbian, kruskal, asian, objectification, exploitative, pbs,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7895 0.0309 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7767 0.0295 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7390 0.0297 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7065 0.0296 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7714 0.0299 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6955 0.0296 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7043 0.0296 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7097 0.0295 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7034 0.0293 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6507 0.0294 sec/batch
# Nearest to known: helping, kepler, adds, serene, couture, ostensibly, score, khattab,
# Nearest to during: milton, fugees, instituting, talks, claim, knowledgeable, heligoland, swayed,
# Nearest to see: assiniboine, circulates, bakker, crenshaw, honeys, reality, categorised, capone,
# Nearest to zero: total, one, otto, impressive, demerara, nicolas, ipa, icy,
# Nearest to when: hulk, emendations, saturated, lustrous, slobodan, mock, poles, laing,
# Nearest to most: syllable, ottawa, trademarked, computer, kahan, whittier, phases, preregular,
# Nearest to about: necessary, lov, anniversary, mare, unchangeable, fed, concerned, inviolable,
# Nearest to all: securities, trading, reinsurance, camping, kinds, peninsula, jets, aerobics,
# Nearest to san: sydney, synthetic, campus, including, st, caucasus, presumes, unresponsive,
# Nearest to older: isolating, is, radium, powerplant, sauk, cipher, chosen, capensis,
# Nearest to heavy: fuses, observers, singaporean, shared, casualties, dicke, element, spectrometer,
# Nearest to road: oecd, sepoy, juliana, whistles, cocker, gladio, ancestry, penultimate,
# Nearest to primarily: tirpitz, settings, bologna, conciliatory, pbsuccess, legality, slovenia, aimed,
# Nearest to animals: lines, roux, runic, gluing, alice, leather, ndische, omnipotent,
# Nearest to channel: lysander, sukhum, beery, signified, assign, lie, declared, maryland,
# Nearest to account: polytheism, africans, exploitative, lesbian, kruskal, objectification, incompetent, asian,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6628 0.0307 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6682 0.0297 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6209 0.0298 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6312 0.0297 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6313 0.0294 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6376 0.0294 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5937 0.0219 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5310 0.0297 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5045 0.0298 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5184 0.0298 sec/batch
# Nearest to known: helping, kepler, khattab, couture, adds, serene, heenan, inaccurately,
# Nearest to during: milton, fugees, instituting, heligoland, knowledgeable, claim, convoked, talks,
# Nearest to see: circulates, honeys, archeology, assiniboine, bakker, reality, crenshaw, blastocyst,
# Nearest to zero: total, one, nicolas, six, impressive, writer, otto, demerara,
# Nearest to when: hulk, saturated, mock, vanunu, lustrous, laing, emendations, consolidated,
# Nearest to most: syllable, trademarked, computer, ottawa, kahan, preregular, whittier, or,
# Nearest to about: necessary, lov, anniversary, unchangeable, mare, deepwater, concerned, inviolable,
# Nearest to all: securities, trading, camping, aerobics, laserdisc, where, reinsurance, zheng,
# Nearest to san: sydney, synthetic, st, unresponsive, campus, salom, caucasus, fink,
# Nearest to older: isolating, is, sauk, radium, powerplant, cipher, chosen, capensis,
# Nearest to heavy: fuses, singaporean, observers, dicke, casualties, shared, spectrometer, pantheistic,
# Nearest to road: oecd, juliana, sepoy, ancestry, cocker, penultimate, whistles, gladio,
# Nearest to primarily: tirpitz, legality, pbsuccess, settings, current, bologna, conciliatory, onslaught,
# Nearest to animals: roux, gluing, lines, leather, runic, omnipotent, alice, presumably,
# Nearest to channel: sukhum, lysander, beery, signified, assign, kesteven, maryland, lie,
# Nearest to account: polytheism, africans, exploitative, kruskal, lesbian, notice, objectification, baryonic,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.5087 0.0307 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5118 0.0295 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4731 0.0296 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5159 0.0294 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4888 0.0295 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4659 0.0296 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4527 0.0295 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4168 0.0295 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4177 0.0296 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4275 0.0293 sec/batch
# Nearest to known: helping, kepler, couture, adds, khattab, mimic, serene, inaccurately,
# Nearest to during: fugees, milton, heligoland, instituting, mnr, sectors, amakusa, convoked,
# Nearest to see: circulates, honeys, archeology, assiniboine, ravage, bakker, blastocyst, starr,
# Nearest to zero: total, one, impressive, six, five, ipa, nicolas, frosts,
# Nearest to when: saturated, hulk, vanunu, mock, spotless, behaviors, abuser, stub,
# Nearest to most: syllable, trademarked, computer, kahan, ottawa, dominant, capability, preregular,
# Nearest to about: necessary, lov, anniversary, unchangeable, concerned, deepwater, fed, inviolable,
# Nearest to all: securities, where, trading, aerobics, camping, wicklow, zheng, antigens,
# Nearest to san: sydney, campus, st, salom, transportation, unresponsive, caucasus, businessman,
# Nearest to older: isolating, is, radium, sauk, chosen, powerplant, capensis, females,
# Nearest to heavy: fuses, singaporean, casualties, dicke, observers, shared, spectrometer, element,
# Nearest to road: oecd, juliana, cocker, ancestry, sepoy, entourage, penultimate, cha,
# Nearest to primarily: current, tirpitz, conciliatory, pbsuccess, bologna, aimed, legality, bytecode,
# Nearest to animals: roux, leather, gluing, lines, omnipotent, runic, soloing, ayyavazhi,
# Nearest to channel: sukhum, beery, lysander, assign, bbs, thrilling, signified, fright,
# Nearest to account: polytheism, africans, exploitative, kruskal, lesbian, notice, baryonic, intervocalic,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4263 0.0307 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4046 0.0294 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4541 0.0296 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3986 0.0295 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4212 0.0296 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4298 0.0296 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.4020 0.0297 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3673 0.0297 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.3931 0.0297 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3533 0.0297 sec/batch
# Nearest to known: helping, kepler, couture, khattab, aztecs, adds, mimic, cherub,
# Nearest to during: fugees, mnr, milton, instituting, heligoland, exclaims, scarecrow, talks,
# Nearest to see: assiniboine, circulates, archeology, honeys, bakker, mcaleese, ravage, references,
# Nearest to zero: total, one, six, five, three, four, impressive, nicolas,
# Nearest to when: hulk, saturated, vanunu, mock, stub, spotless, depending, behaviors,
# Nearest to most: syllable, trademarked, computer, kahan, capability, ottawa, dominant, displace,
# Nearest to about: lov, necessary, anniversary, unchangeable, concerned, boule, shorter, mare,
# Nearest to all: securities, where, trading, aerobics, camping, zheng, locking, reinsurance,
# Nearest to san: sydney, campus, st, transportation, salom, columbia, businessman, hilly,
# Nearest to older: isolating, is, families, females, sauk, radium, oshkosh, capensis,
# Nearest to heavy: fuses, singaporean, casualties, dicke, heavier, observers, spectrometer, battle,
# Nearest to road: juliana, oecd, cocker, sepoy, crosses, ancestry, entourage, manche,
# Nearest to primarily: tirpitz, conciliatory, bologna, pbsuccess, current, slovenia, onslaught, legality,
# Nearest to animals: leather, gluing, omnipotent, roux, runic, gaseous, elevators, lines,
# Nearest to channel: sukhum, beery, lysander, cable, wir, bbs, thrilling, fright,
# Nearest to account: polytheism, exploitative, africans, kruskal, baryonic, notice, incompetent, intervocalic,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3849 0.0307 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.4036 0.0296 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3946 0.0297 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3516 0.0294 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.4177 0.0296 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3886 0.0296 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3981 0.0298 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3851 0.0296 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3645 0.0297 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3368 0.0294 sec/batch
# Nearest to known: helping, kepler, cherub, khattab, sub, couture, medallion, aztecs,
# Nearest to during: mnr, fugees, instituting, heligoland, milton, scarecrow, convoked, talks,
# Nearest to see: circulates, assiniboine, references, archeology, information, bakker, honeys, list,
# Nearest to zero: total, one, six, five, three, four, impressive, two,
# Nearest to when: saturated, vanunu, hulk, depending, mock, poles, boilers, superfluidity,
# Nearest to most: syllable, trademarked, kahan, computer, certifications, dominant, displace, ottawa,
# Nearest to about: lov, necessary, pseudepigraphical, unchangeable, anniversary, boule, inviolable, fractures,
# Nearest to all: securities, aerobics, where, trading, kingdom, zheng, camping, reinsurance,
# Nearest to san: sydney, campus, st, salom, transportation, columbia, navassa, hilly,
# Nearest to older: isolating, is, families, females, radium, sauk, capensis, oshkosh,
# Nearest to heavy: casualties, fuses, singaporean, heavier, havilland, dicke, spectrometer, battle,
# Nearest to road: oecd, crosses, single, juliana, cocker, manche, sepoy, entourage,
# Nearest to primarily: tirpitz, pbsuccess, bologna, conciliatory, slovenia, onslaught, legality, current,
# Nearest to animals: leather, gluing, sugar, roux, omnipotent, elevators, runic, gaseous,
# Nearest to channel: cable, sukhum, lysander, wir, beery, news, assign, bbs,
# Nearest to account: polytheism, africans, kruskal, exploitative, baryonic, notice, intervocalic, lesbian,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3421 0.0307 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2847 0.0297 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3456 0.0297 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3634 0.0297 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3874 0.0295 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2944 0.0296 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3262 0.0295 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3499 0.0296 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2115 0.0294 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.3077 0.0296 sec/batch
# Nearest to known: kepler, helping, couture, aztecs, cherub, khattab, mimic, rabbani,
# Nearest to during: mnr, fugees, heligoland, instituting, bolshevik, negotiators, milton, scarecrow,
# Nearest to see: references, list, blastocyst, assiniboine, archeology, circulates, ashram, commemoration,
# Nearest to zero: one, total, six, five, three, four, two, deaths,
# Nearest to when: saturated, hulk, vanunu, boilers, mock, opel, superfluidity, depending,
# Nearest to most: syllable, trademarked, dominant, certifications, kahan, dravidians, displace, computer,
# Nearest to about: lov, necessary, fractures, anniversary, pseudepigraphical, unchangeable, dickson, boule,
# Nearest to all: securities, aerobics, trading, zheng, kingdom, where, reinsurance, imagines,
# Nearest to san: sydney, campus, st, salom, transportation, columbia, sandawe, navassa,
# Nearest to older: families, is, females, isolating, sauk, radium, oshkosh, capensis,
# Nearest to heavy: casualties, fuses, singaporean, heavier, havilland, spectrometer, battle, projectile,
# Nearest to road: oecd, single, crosses, railway, zebra, juliana, manche, cocker,
# Nearest to primarily: pbsuccess, slovenia, bologna, tirpitz, onslaught, aimed, conciliatory, balinese,
# Nearest to animals: leather, gluing, omnipotent, sugar, roux, elevators, structurally, soil,
# Nearest to channel: sukhum, cable, lysander, beery, wir, svga, news, radios,
# Nearest to account: polytheism, kruskal, africans, exploitative, lesbian, notice, intervocalic, baryonic,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3019 0.0307 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.3091 0.0295 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3363 0.0140 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2519 0.0295 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2247 0.0298 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2285 0.0299 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2391 0.0296 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2168 0.0296 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2394 0.0294 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1970 0.0295 sec/batch
# Nearest to known: cherub, kepler, khattab, sub, helping, couture, including, aztecs,
# Nearest to during: mnr, fugees, heligoland, instituting, mulk, scarecrow, zangger, exclaims,
# Nearest to see: list, references, information, blastocyst, archeology, honeys, commemoration, ashram,
# Nearest to zero: one, total, five, three, six, four, per, two,
# Nearest to when: saturated, hulk, vanunu, boilers, mock, opel, midst, vertically,
# Nearest to most: trademarked, syllable, dominant, computer, kahan, dravidians, habitation, certifications,
# Nearest to about: lov, fractures, necessary, anniversary, unchangeable, dickson, pseudepigraphical, boule,
# Nearest to all: securities, aerobics, trading, where, leroux, zheng, camping, kingdom,
# Nearest to san: sydney, campus, st, transportation, columbia, salom, navassa, sandawe,
# Nearest to older: families, females, is, isolating, sauk, household, radium, botanists,
# Nearest to heavy: casualties, fuses, heavier, singaporean, havilland, battle, spectrometer, attacked,
# Nearest to road: railway, crosses, zebra, freeway, single, juliana, roads, manche,
# Nearest to primarily: pbsuccess, slovenia, balinese, onslaught, bologna, inflate, tirpitz, yag,
# Nearest to animals: leather, gluing, sugar, elevators, omnipotent, oceanic, structurally, roux,
# Nearest to channel: cable, sukhum, lysander, wir, news, presentations, svga, radios,
# Nearest to account: polytheism, kruskal, africans, exploitative, intervocalic, notice, lesbian, baryonic,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2358 0.0308 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2376 0.0296 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.1963 0.0296 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1104 0.0296 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1777 0.0297 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1686 0.0296 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1652 0.0295 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1938 0.0296 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2078 0.0295 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1744 0.0296 sec/batch
# Nearest to known: cherub, sub, khattab, rabbani, helping, kepler, including, mimic,
# Nearest to during: mnr, fugees, heligoland, instituting, scarecrow, transporter, mulk, bolshevik,
# Nearest to see: references, list, information, archeology, blastocyst, honeys, ashram, commemoration,
# Nearest to zero: one, three, total, four, five, six, two, per,
# Nearest to when: saturated, vanunu, boilers, hulk, mock, vertically, opel, depending,
# Nearest to most: syllable, computer, trademarked, certifications, dominant, dravidians, displace, smokes,
# Nearest to about: lov, necessary, unchangeable, fractures, dickson, pseudepigraphical, anniversary, details,
# Nearest to all: securities, where, aerobics, leroux, generality, kingdom, zheng, events,
# Nearest to san: sydney, campus, columbia, st, salom, transportation, boland, navassa,
# Nearest to older: families, females, is, isolating, household, sauk, householder, radium,
# Nearest to heavy: casualties, battle, heavier, singaporean, fuses, combat, attacked, hinterland,
# Nearest to road: freeway, crosses, railway, roads, bandleaders, cocker, juliana, zebra,
# Nearest to primarily: balinese, pbsuccess, bologna, tirpitz, slovenia, aimed, yag, onslaught,
# Nearest to animals: leather, elevators, gluing, bred, oceanic, sugar, cattle, soil,
# Nearest to channel: cable, sukhum, news, lysander, presentations, wir, svga, radios,
# Nearest to account: polytheism, kruskal, africans, exploitative, notice, intervocalic, baryonic, cosmology,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1664 0.0307 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2607 0.0296 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1775 0.0296 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1318 0.0297 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1722 0.0295 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1832 0.0295 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2181 0.0296 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1683 0.0294 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1433 0.0296 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1757 0.0297 sec/batch
# Nearest to known: khattab, cherub, sub, rabbani, including, helping, kepler, couture,
# Nearest to during: mnr, fugees, heligoland, instituting, caterina, scarecrow, transporter, benefitted,
# Nearest to see: references, list, information, com, archeology, commemoration, honeys, pages,
# Nearest to zero: one, four, total, three, five, six, two, seven,
# Nearest to when: saturated, vanunu, hulk, mock, boilers, vertically, depending, opel,
# Nearest to most: computer, syllable, trademarked, certifications, dravidians, dominant, displace, smokes,
# Nearest to about: lov, necessary, anniversary, pseudepigraphical, dickson, fractures, unchangeable, lisan,
# Nearest to all: generality, where, securities, aerobics, zheng, completing, sint, events,
# Nearest to san: sydney, campus, boland, st, salom, transportation, columbia, navassa,
# Nearest to older: families, females, is, isolating, sauk, household, householder, lauper,
# Nearest to heavy: casualties, heavier, attacked, singaporean, fuses, battle, hinterland, combat,
# Nearest to road: freeway, crosses, roads, single, cocker, bandleaders, entourage, railway,
# Nearest to primarily: balinese, bologna, pbsuccess, onslaught, tirpitz, aimed, slovenia, conciliatory,
# Nearest to animals: leather, cattle, elevators, bred, gluing, oceanic, ears, soil,
# Nearest to channel: cable, sukhum, news, presentations, lysander, wir, radios, televisions,
# Nearest to account: kruskal, polytheism, africans, baryonic, cosmology, kw, notice, redistributed,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2034 0.0309 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1732 0.0297 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1484 0.0295 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1915 0.0296 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1349 0.0296 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1367 0.0295 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1671 0.0296 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1265 0.0297 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.2133 0.0298 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2119 0.0297 sec/batch
# Nearest to known: khattab, rabbani, cherub, including, organists, helping, couture, sub,
# Nearest to during: mnr, fugees, heligoland, in, caterina, instituting, transporter, troppo,
# Nearest to see: references, list, information, commemoration, com, pages, archeology, page,
# Nearest to zero: one, four, three, five, two, six, total, nine,
# Nearest to when: saturated, vanunu, hulk, mock, boilers, depending, kidnapped, opel,
# Nearest to most: computer, trademarked, dravidians, smokes, syllable, certifications, bhasha, dominant,
# Nearest to about: lov, dickson, anniversary, pseudepigraphical, necessary, fractures, boule, lisan,
# Nearest to all: securities, kingdom, where, zheng, leroux, breuer, aerobics, generality,
# Nearest to san: sydney, campus, st, boland, navassa, salom, transportation, chris,
# Nearest to older: families, females, is, isolating, sauk, householder, household, lauper,
# Nearest to heavy: casualties, fuses, heavier, attacked, singaporean, hinterland, battle, havilland,
# Nearest to road: freeway, roads, bandleaders, crosses, cocker, single, railway, cha,
# Nearest to primarily: balinese, bologna, onslaught, pbsuccess, aimed, tirpitz, slovenia, conciliatory,
# Nearest to animals: cattle, leather, bred, elevators, oceanic, gluing, vortigern, structurally,
# Nearest to channel: cable, sukhum, news, lysander, radios, presentations, televisions, wir,
# Nearest to account: kruskal, polytheism, cosmology, notice, africans, redistributed, kw, implicitly,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2169 0.0306 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1224 0.0296 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1399 0.0295 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1119 0.0296 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0808 0.0296 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1603 0.0297 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1374 0.0297 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1329 0.0295 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1859 0.0061 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1123 0.0295 sec/batch
# Nearest to known: including, cherub, organists, khattab, sub, rabbani, helping, eliyahu,
# Nearest to during: mnr, fugees, heligoland, transporter, monsoons, troppo, negotiators, combined,
# Nearest to see: references, list, information, pages, blastocyst, archeology, commemoration, ashram,
# Nearest to zero: one, five, four, three, two, six, total, rate,
# Nearest to when: saturated, hulk, mock, vanunu, boilers, opel, vertically, depending,
# Nearest to most: computer, trademarked, smokes, dravidians, ottawa, bhasha, certifications, renovations,
# Nearest to about: lov, anniversary, dickson, fractures, lisan, pseudepigraphical, necessary, lilongwe,
# Nearest to all: generality, securities, where, trading, aerobics, income, past, zheng,
# Nearest to san: campus, sydney, st, boland, sandawe, bogdan, navassa, transportation,
# Nearest to older: families, females, is, sauk, isolating, householder, household, botanists,
# Nearest to heavy: casualties, heavier, fuses, attacked, battle, singaporean, hinterland, hyllus,
# Nearest to road: roads, freeway, railway, bandleaders, crosses, wadis, single, commuter,
# Nearest to primarily: balinese, pbsuccess, bologna, slovenia, onslaught, aimed, tirpitz, coconuts,
# Nearest to animals: bred, leather, cattle, elevators, ears, oceanic, herd, vortigern,
# Nearest to channel: cable, sukhum, presentations, news, lysander, televisions, radios, wir,
# Nearest to account: kruskal, polytheism, kw, cosmology, africans, redistributed, notice, lesbian,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0942 0.0308 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0653 0.0298 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.1150 0.0296 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0484 0.0298 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0708 0.0298 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0249 0.0297 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0972 0.0296 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.1056 0.0295 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1061 0.0294 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0571 0.0294 sec/batch
# Nearest to known: including, cherub, khattab, organists, sub, rabbani, kepler, helping,
# Nearest to during: mnr, transporter, fugees, heligoland, in, zangger, monsoons, combined,
# Nearest to see: references, list, information, commemoration, com, blastocyst, archeology, page,
# Nearest to zero: five, one, three, four, two, total, six, seven,
# Nearest to when: saturated, mock, boilers, vanunu, midst, opel, depending, vertically,
# Nearest to most: computer, bhasha, dravidians, trademarked, smokes, and, syllable, renovations,
# Nearest to about: lov, fractures, anniversary, dickson, lisan, lilongwe, details, pseudepigraphical,
# Nearest to all: where, generality, securities, aerobics, slam, income, past, trading,
# Nearest to san: campus, sydney, boland, navassa, st, bogdan, chris, transportation,
# Nearest to older: families, females, household, is, householder, sauk, lauper, isolating,
# Nearest to heavy: casualties, heavier, fuses, attacked, battle, singaporean, hyllus, hinterland,
# Nearest to road: roads, freeway, railway, commuter, crosses, bandleaders, wadis, bridges,
# Nearest to primarily: balinese, bologna, slovenia, aimed, onslaught, pbsuccess, tirpitz, corrino,
# Nearest to animals: ears, bred, elevators, cattle, vortigern, resurrection, leather, omnipotent,
# Nearest to channel: cable, sukhum, presentations, news, lysander, pbs, wir, radios,
# Nearest to account: kruskal, polytheism, kw, notice, cosmology, africans, redistributed, implicitly,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0219 0.0306 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0336 0.0294 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 3.9945 0.0293 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0461 0.0295 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0726 0.0296 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0636 0.0295 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0514 0.0294 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1171 0.0294 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0639 0.0296 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0435 0.0294 sec/batch
# Nearest to known: including, cherub, organists, sub, khattab, novelties, rabbani, eliyahu,
# Nearest to during: mnr, transporter, fugees, troppo, scarecrow, heligoland, benefitted, combined,
# Nearest to see: references, list, commemoration, information, ashram, com, bab, archeology,
# Nearest to zero: five, one, three, two, four, six, seven, nine,
# Nearest to when: saturated, mock, vanunu, boilers, midst, opel, vertically, depending,
# Nearest to most: displace, computer, dravidians, smokes, trademarked, and, habitation, renovations,
# Nearest to about: lov, anniversary, dickson, fractures, lisan, pseudepigraphical, unchangeable, necessary,
# Nearest to all: generality, where, securities, events, completing, aerobics, number, venizelos,
# Nearest to san: campus, sydney, boland, navassa, transportation, bogdan, synthetic, st,
# Nearest to older: families, females, household, is, householder, median, individuals, households,
# Nearest to heavy: casualties, heavier, fuses, attacked, singaporean, battle, hyllus, hinterland,
# Nearest to road: roads, freeway, railway, bridges, crosses, commuter, bandleaders, wadis,
# Nearest to primarily: balinese, bologna, aimed, pbsuccess, tirpitz, onslaught, slovenia, coconuts,
# Nearest to animals: bred, ears, herbivorous, herd, cattle, elevators, oceanic, leather,
# Nearest to channel: cable, sukhum, presentations, news, lysander, pbs, wir, kesteven,
# Nearest to account: kw, kruskal, notice, cosmology, africans, redistributed, polytheism, regarding,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0908 0.0308 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0606 0.0295 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0629 0.0296 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0651 0.0294 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0683 0.0297 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0612 0.0296 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0658 0.0295 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0528 0.0298 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0650 0.0297 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0678 0.0297 sec/batch
# Nearest to known: including, organists, cherub, sub, novelties, khattab, medallion, rabbani,
# Nearest to during: mnr, in, transporter, fugees, heligoland, zangger, intellectuals, caterina,
# Nearest to see: references, commemoration, list, ashram, information, bab, non, com,
# Nearest to zero: five, one, two, three, four, seven, six, nine,
# Nearest to when: saturated, boilers, midst, vanunu, opel, mock, turbulent, depending,
# Nearest to most: dravidians, smokes, displace, bhasha, dexterity, trademarked, computer, grotesque,
# Nearest to about: lov, anniversary, dickson, pseudepigraphical, fractures, lisan, unchangeable, details,
# Nearest to all: generality, where, income, securities, kingdom, aerobics, breuer, completing,
# Nearest to san: campus, sydney, boland, navassa, transportation, salom, francisco, slopes,
# Nearest to older: families, females, household, is, householder, individuals, median, versus,
# Nearest to heavy: heavier, casualties, fuses, hyllus, attacked, singaporean, hinterland, spectrometer,
# Nearest to road: roads, freeway, railway, bridges, commuter, crosses, rail, bandleaders,
# Nearest to primarily: balinese, aimed, bologna, onslaught, slovenia, tirpitz, pbsuccess, coconuts,
# Nearest to animals: bred, ears, herd, herbivorous, cattle, animal, resurrection, minke,
# Nearest to channel: cable, sukhum, presentations, pbs, news, lysander, kesteven, wir,
# Nearest to account: kw, kruskal, cosmology, notice, redistributed, polytheism, africans, regarding,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0578 0.0308 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0170 0.0295 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0190 0.0296 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0762 0.0298 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0709 0.0298 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1158 0.0296 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1376 0.0298 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0604 0.0295 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0548 0.0294 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0696 0.0294 sec/batch
# Nearest to known: including, organists, khattab, cherub, novelties, rabbani, sub, medallion,
# Nearest to during: in, mnr, transporter, zangger, heligoland, monsoons, caterina, negotiators,
# Nearest to see: references, list, information, ashram, commemoration, external, bab, com,
# Nearest to zero: one, five, two, four, three, six, seven, nine,
# Nearest to when: saturated, boilers, turbulent, opel, mock, midst, vanunu, depending,
# Nearest to most: dravidians, bhasha, and, smokes, dexterity, displace, trademarked, renovations,
# Nearest to about: lov, anniversary, dickson, fractures, pseudepigraphical, lisan, postings, minorities,
# Nearest to all: generality, income, where, securities, monotone, events, slam, breuer,
# Nearest to san: campus, sydney, boland, navassa, francisco, bogdan, mitigation, salom,
# Nearest to older: families, females, household, householder, is, individuals, households, median,
# Nearest to heavy: heavier, casualties, fuses, hyllus, attacked, hinterland, singaporean, havilland,
# Nearest to road: roads, freeway, railway, bridges, crosses, commuter, bandleaders, wadis,
# Nearest to primarily: balinese, aimed, bologna, bytecode, coconuts, slovenia, braudel, onslaught,
# Nearest to animals: bred, herbivorous, animal, ears, cattle, minke, herd, resurrection,
# Nearest to channel: cable, sukhum, pbs, presentations, news, kesteven, lysander, wir,
# Nearest to account: kw, kruskal, notice, cosmology, regarding, redistributed, polytheism, africans,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 4.0011 0.0308 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0314 0.0298 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0308 0.0297 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0391 0.0297 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0912 0.0296 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0516 0.0276 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0117 0.0296 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9717 0.0297 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0373 0.0297 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9707 0.0298 sec/batch
# Nearest to known: including, organists, cherub, khattab, novelties, medallion, sub, kepler,
# Nearest to during: mnr, in, transporter, combined, heligoland, zangger, monsoons, troppo,
# Nearest to see: references, list, external, information, commemoration, ashram, bab, variables,
# Nearest to zero: one, three, two, five, four, six, seven, nine,
# Nearest to when: saturated, boilers, turbulent, mock, opel, midst, fanaticism, vanunu,
# Nearest to most: dexterity, smokes, dravidians, grotesque, bhasha, trademarked, oud, computer,
# Nearest to about: lov, anniversary, pseudepigraphical, dickson, fractures, lisan, unchangeable, uncertainties,
# Nearest to all: generality, income, slam, events, where, securities, number, aerobics,
# Nearest to san: campus, boland, francisco, sydney, navassa, rez, transportation, mitigation,
# Nearest to older: families, females, household, householder, is, median, households, individuals,
# Nearest to heavy: heavier, casualties, fuses, hyllus, attacked, migrants, singaporean, hinterland,
# Nearest to road: roads, railway, freeway, bridges, commuter, crosses, wadis, bandleaders,
# Nearest to primarily: balinese, aimed, coconuts, bytecode, onslaught, twayne, braudel, pbsuccess,
# Nearest to animals: bred, animal, herbivorous, ears, minke, cattle, resurrection, prana,
# Nearest to channel: cable, sukhum, presentations, pbs, news, kesteven, lysander, wir,
# Nearest to account: kw, kruskal, notice, regarding, polytheism, cosmology, africans, redistributed,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9961 0.0308 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9695 0.0296 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0087 0.0294 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0236 0.0296 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0200 0.0296 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0039 0.0297 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9246 0.0301 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9402 0.0296 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9363 0.0296 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9874 0.0295 sec/batch
# Nearest to known: including, organists, novelties, khattab, sub, cherub, medallion, rabbani,
# Nearest to during: mnr, transporter, in, combined, monsoons, zangger, troppo, heligoland,
# Nearest to see: list, references, information, external, com, bab, page, ashram,
# Nearest to zero: one, three, five, four, two, six, seven, nine,
# Nearest to when: saturated, boilers, opel, midst, mock, turbulent, depending, radiotherapy,
# Nearest to most: and, displace, renovations, dexterity, coolest, occurrences, smokes, prominent,
# Nearest to about: lov, dickson, anniversary, fractures, pseudepigraphical, lisan, postings, details,
# Nearest to all: generality, number, where, income, securities, events, for, monotone,
# Nearest to san: francisco, campus, boland, navassa, sydney, rez, irvine, bogdan,
# Nearest to older: families, females, household, householder, households, median, is, versus,
# Nearest to heavy: casualties, heavier, fuses, attacked, migrants, hyllus, battle, hinterland,
# Nearest to road: roads, railway, freeway, commuter, bridges, crosses, rail, wadis,
# Nearest to primarily: balinese, aimed, coconuts, bytecode, bologna, braudel, pbsuccess, twayne,
# Nearest to animals: animal, bred, minke, ears, herbivorous, cattle, prana, resurrection,
# Nearest to channel: cable, sukhum, presentations, pbs, kesteven, news, lysander, wir,
# Nearest to account: kw, kruskal, notice, regarding, redistributed, africans, cosmology, fertility,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9902 0.0307 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0027 0.0295 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9491 0.0295 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0154 0.0296 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0298 0.0298 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9433 0.0296 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.0247 0.0296 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9998 0.0297 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9849 0.0296 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0012 0.0296 sec/batch
# Nearest to known: organists, including, novelties, khattab, sub, cherub, medallion, nurseries,
# Nearest to during: mnr, transporter, in, troppo, combined, caterina, fugees, scarecrow,
# Nearest to see: list, references, external, information, commemoration, com, page, ashram,
# Nearest to zero: one, two, five, four, three, six, seven, nine,
# Nearest to when: saturated, boilers, mock, turbulent, depending, opel, hulk, midst,
# Nearest to most: renovations, occurrences, coolest, dexterity, grotesque, oud, smokes, syllable,
# Nearest to about: lov, anniversary, dickson, pseudepigraphical, postings, fractures, uncertainties, depth,
# Nearest to all: generality, where, income, for, number, securities, events, slam,
# Nearest to san: francisco, campus, boland, navassa, rez, sydney, mitigation, transportation,
# Nearest to older: families, females, household, householder, median, households, individuals, versus,
# Nearest to heavy: casualties, heavier, fuses, migrants, hyllus, attacked, spectrometer, boasted,
# Nearest to road: roads, railway, freeway, bridges, commuter, crosses, rail, wadis,
# Nearest to primarily: balinese, aimed, bytecode, twayne, bologna, coconuts, categories, onslaught,
# Nearest to animals: bred, animal, herbivorous, minke, ears, cattle, prana, monk,
# Nearest to channel: cable, sukhum, presentations, pbs, lysander, news, kesteven, aired,
# Nearest to account: kw, kruskal, regarding, notice, redistributed, cosmology, africans, implicitly,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9987 0.0307 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9802 0.0296 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9985 0.0295 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9770 0.0296 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0093 0.0297 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0009 0.0298 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9758 0.0295 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9687 0.0299 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9492 0.0295 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0342 0.0297 sec/batch
# Nearest to known: including, organists, novelties, khattab, nurseries, cherub, sub, medallion,
# Nearest to during: mnr, in, transporter, combined, troppo, zangger, caterina, heligoland,
# Nearest to see: list, references, external, information, non, com, topics, variables,
# Nearest to zero: two, five, one, four, three, six, seven, nine,
# Nearest to when: saturated, turbulent, boilers, depending, vanunu, opel, hulk, symbols,
# Nearest to most: and, dexterity, coolest, are, bhasha, occurrences, renovations, dravidians,
# Nearest to about: lov, pseudepigraphical, anniversary, dickson, uncertainties, postings, minorities, fractures,
# Nearest to all: for, income, where, kingdom, generality, number, breuer, securities,
# Nearest to san: francisco, campus, boland, navassa, rez, mitigation, sydney, irvine,
# Nearest to older: families, females, household, householder, median, is, versus, households,
# Nearest to heavy: casualties, fuses, migrants, heavier, bands, spectrometer, hyllus, honduran,
# Nearest to road: roads, railway, freeway, bridges, commuter, rail, crosses, wadis,
# Nearest to primarily: balinese, aimed, categories, twayne, onslaught, bytecode, braudel, bologna,
# Nearest to animals: animal, bred, herbivorous, minke, ears, resurrection, prana, monk,
# Nearest to channel: cable, sukhum, presentations, pbs, upn, aired, kesteven, takeovers,
# Nearest to account: kw, kruskal, regarding, notice, redistributed, cosmology, africans, poems,
# ...
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 3.8102 0.0294 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.8832 0.0295 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8774 0.0294 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8376 0.0297 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8722 0.0297 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.9039 0.0295 sec/batch
# Nearest to known: including, the, as, commonly, of, be, been, some,
# Nearest to during: in, transporter, combined, until, troppo, the, monsoons, clouds,
# Nearest to see: list, external, of, references, links, or, also, non,
# Nearest to zero: five, one, two, four, three, six, nine, seven,
# Nearest to when: saturated, boilers, after, became, dominoes, this, fanaticism, confident,
# Nearest to most: are, and, be, coolest, widely, to, been, the,
# Nearest to about: zero, five, this, a, lov, to, ibex, have,
# Nearest to all: are, for, where, of, the, those, were, with,
# Nearest to san: francisco, rez, boland, serves, campus, jose, diego, california,
# Nearest to older: families, females, household, husband, median, individuals, householder, versus,
# Nearest to heavy: heavier, fuses, comparatively, wrecks, casualties, spectrometer, boasted, devised,
# Nearest to road: roads, railway, rail, commuter, crosses, wadis, troubles, bridges,
# Nearest to primarily: loretta, balinese, aimed, ets, categories, primary, range, bytecode,
# Nearest to animals: animal, minke, prana, bred, pixar, synonym, heliozoa, lines,
# Nearest to channel: cable, splits, sukhum, aired, presentations, pbs, blocker, lie,
# Nearest to account: kw, regarding, accounts, notice, inactivation, kruskal, belshazzar, mackie,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8514 0.0308 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8494 0.0294 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8699 0.0296 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8496 0.0296 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8610 0.0294 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8728 0.0296 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8774 0.0294 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8347 0.0295 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8684 0.0295 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8299 0.0297 sec/batch
# Nearest to known: including, the, of, as, commonly, been, be, in,
# Nearest to during: in, transporter, troppo, combined, the, until, mnr, delivered,
# Nearest to see: external, list, of, references, links, also, the, a,
# Nearest to zero: five, two, one, four, three, nine, seven, six,
# Nearest to when: saturated, boilers, became, this, after, bleda, turbulent, dominoes,
# Nearest to most: are, and, been, coolest, be, widely, in, occurrences,
# Nearest to about: zero, five, this, lov, have, to, pseudepigraphical, two,
# Nearest to all: for, those, are, of, where, with, living, and,
# Nearest to san: francisco, rez, boland, diego, california, serves, buenos, jose,
# Nearest to older: families, household, husband, females, householder, median, versus, individuals,
# Nearest to heavy: heavier, comparatively, fuses, wrecks, devised, spectrometer, therapy, boasted,
# Nearest to road: roads, railway, rail, commuter, crosses, wadis, troubles, bridges,
# Nearest to primarily: balinese, loretta, aimed, ets, scandinavians, primary, categories, braudel,
# Nearest to animals: animal, minke, prana, synonym, heliozoa, pixar, lines, bred,
# Nearest to channel: cable, splits, aired, sukhum, presentations, pbs, blocker, lie,
# Nearest to account: kw, accounts, regarding, notice, mackie, poems, weathering, spatiality,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8748 0.0310 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8646 0.0296 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8152 0.0296 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8102 0.0295 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.9061 0.0296 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8480 0.0297 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9427 0.0296 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8866 0.0297 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.8923 0.0296 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8110 0.0299 sec/batch
# Nearest to known: including, the, commonly, been, as, novelties, some, ostensibly,
# Nearest to during: in, the, combined, troppo, mnr, transporter, until, was,
# Nearest to see: list, external, references, links, of, also, non, or,
# Nearest to zero: five, two, one, four, three, nine, six, seven,
# Nearest to when: after, became, boilers, this, turbulent, saturated, bleda, fanaticism,
# Nearest to most: and, are, been, coolest, in, have, occurrences, suggested,
# Nearest to about: zero, to, this, five, a, have, two, for,
# Nearest to all: for, of, with, those, two, living, are, one,
# Nearest to san: francisco, rez, boland, diego, california, serves, jose, navassa,
# Nearest to older: families, females, household, husband, householder, median, versus, individuals,
# Nearest to heavy: heavier, fuses, comparatively, wrecks, migrants, therapy, devised, spectrometer,
# Nearest to road: roads, railway, rail, wadis, commuter, crosses, troubles, capping,
# Nearest to primarily: balinese, loretta, aimed, ets, braudel, scandinavians, categories, primary,
# Nearest to animals: animal, minke, heliozoa, synonym, prana, lines, pixar, eschrichtius,
# Nearest to channel: splits, cable, sukhum, aired, presentations, blocker, corner, ttt,
# Nearest to account: kw, accounts, regarding, poems, notice, thurston, mackie, kruskal,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7857 0.0306 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8619 0.0296 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.8029 0.0297 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8505 0.0295 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8488 0.0294 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8633 0.0295 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8920 0.0175 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8148 0.0296 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8268 0.0297 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8357 0.0298 sec/batch
# Nearest to known: including, the, commonly, been, as, some, of, be,
# Nearest to during: in, the, combined, clouds, transporter, troppo, until, monsoons,
# Nearest to see: external, list, of, links, references, also, or, topics,
# Nearest to zero: two, one, five, four, three, six, nine, seven,
# Nearest to when: after, became, this, boilers, at, saturated, the, but,
# Nearest to most: are, and, been, be, coolest, occurrences, throughout, widely,
# Nearest to about: zero, this, a, five, to, two, have, ibex,
# Nearest to all: for, those, living, where, with, of, are, income,
# Nearest to san: francisco, rez, boland, california, diego, outgrown, jose, serves,
# Nearest to older: families, husband, females, household, median, householder, versus, individuals,
# Nearest to heavy: heavier, fuses, wrecks, devised, comparatively, migrants, casualties, therapy,
# Nearest to road: roads, railway, rail, wadis, crosses, commuter, troubles, wanderers,
# Nearest to primarily: loretta, balinese, ets, aimed, scandinavians, primary, categories, braudel,
# Nearest to animals: animal, minke, synonym, prana, lines, eschrichtius, monk, glutamic,
# Nearest to channel: splits, cable, sukhum, presentations, aired, pbs, blocker, corner,
# Nearest to account: kw, accounts, regarding, poems, mackie, belshazzar, mecklenburg, notice,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8246 0.0312 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8092 0.0296 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8273 0.0296 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7841 0.0296 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8446 0.0294 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8325 0.0296 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8768 0.0297 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7593 0.0298 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8006 0.0295 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7856 0.0295 sec/batch
# Nearest to known: including, the, as, commonly, been, in, some, of,
# Nearest to during: in, combined, the, until, troppo, transporter, mnr, monsoons,
# Nearest to see: external, list, of, links, also, references, or, com,
# Nearest to zero: five, two, one, four, three, six, nine, seven,
# Nearest to when: after, became, boilers, this, saturated, before, for, to,
# Nearest to most: and, are, coolest, in, been, be, have, throughout,
# Nearest to about: five, zero, this, ibex, two, a, have, pseudepigraphical,
# Nearest to all: for, of, where, and, with, are, the, those,
# Nearest to san: francisco, rez, california, diego, boland, jose, navassa, serves,
# Nearest to older: families, females, household, husband, median, versus, individuals, age,
# Nearest to heavy: heavier, wrecks, fuses, comparatively, casualties, marshalling, migrants, therapy,
# Nearest to road: roads, railway, rail, wadis, crosses, troubles, busiest, commuter,
# Nearest to primarily: balinese, loretta, primary, ets, aimed, scandinavians, range, gluconeogenesis,
# Nearest to animals: animal, minke, synonym, eschrichtius, prana, purposeful, humans, glutamic,
# Nearest to channel: cable, splits, sukhum, aired, presentations, pbs, corner, blocker,
# Nearest to account: kw, accounts, regarding, weathering, notice, belshazzar, spatiality, expired,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7813 0.0307 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8365 0.0295 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8199 0.0297 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8378 0.0296 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8215 0.0297 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.9170 0.0303 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8583 0.0300 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8169 0.0295 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8114 0.0298 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8356 0.0296 sec/batch
# Nearest to known: including, the, commonly, as, some, been, novelties, be,
# Nearest to during: in, until, combined, the, transporter, troppo, was, delivered,
# Nearest to see: external, list, of, links, also, references, the, com,
# Nearest to zero: two, five, one, four, three, nine, six, seven,
# Nearest to when: this, after, became, boilers, saturated, but, a, dominoes,
# Nearest to most: and, are, coolest, be, been, in, have, widely,
# Nearest to about: zero, this, five, to, ibex, and, a, have,
# Nearest to all: for, are, of, with, and, those, where, the,
# Nearest to san: francisco, california, rez, diego, boland, jose, serves, outgrown,
# Nearest to older: families, husband, females, household, versus, median, individuals, age,
# Nearest to heavy: heavier, fuses, wrecks, intense, marshalling, casualties, comparatively, musician,
# Nearest to road: roads, railway, troubles, wadis, rail, crosses, wanderers, commuter,
# Nearest to primarily: loretta, balinese, ets, primary, aimed, range, scandinavians, categories,
# Nearest to animals: animal, minke, synonym, prana, monk, heliozoa, eschrichtius, humans,
# Nearest to channel: cable, splits, sukhum, aired, presentations, corner, ttt, lysander,
# Nearest to account: kw, regarding, accounts, notice, mackie, belshazzar, kruskal, expired,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8670 0.0307 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8489 0.0297 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8145 0.0296 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8403 0.0297 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8775 0.0296 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8367 0.0298 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8318 0.0296 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8306 0.0293 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.7903 0.0296 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8369 0.0296 sec/batch
# Nearest to known: including, the, as, commonly, some, been, of, in,
# Nearest to during: in, until, the, combined, was, particularly, troppo, transporter,
# Nearest to see: external, list, of, links, also, references, a, the,
# Nearest to zero: five, two, one, three, four, six, nine, seven,
# Nearest to when: after, this, became, but, the, a, an, for,
# Nearest to most: are, and, be, the, in, been, other, coolest,
# Nearest to about: zero, to, five, this, have, and, a, ibex,
# Nearest to all: for, are, with, of, the, and, those, where,
# Nearest to san: francisco, rez, california, boland, diego, outgrown, navassa, serves,
# Nearest to older: families, husband, females, household, versus, median, city, individuals,
# Nearest to heavy: heavier, fuses, wrecks, intense, keystrokes, therapy, cantona, spectrometer,
# Nearest to road: roads, railway, rail, troubles, commuter, wadis, crosses, busiest,
# Nearest to primarily: loretta, balinese, ets, primary, range, scandinavians, categories, gluconeogenesis,
# Nearest to animals: animal, minke, synonym, prana, pixar, glutamic, lines, heliozoa,
# Nearest to channel: cable, splits, presentations, sukhum, corner, aired, channels, operator,
# Nearest to account: kw, accounts, regarding, mackie, notice, commentaries, spatiality, belshazzar,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8707 0.0305 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8132 0.0297 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9297 0.0296 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9097 0.0295 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.9056 0.0294 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8406 0.0294 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7652 0.0293 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8425 0.0295 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7379 0.0298 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8528 0.0298 sec/batch
# Nearest to known: including, the, as, commonly, been, be, some, in,
# Nearest to during: in, the, until, was, combined, transporter, particularly, troppo,
# Nearest to see: external, list, of, links, also, references, the, com,
# Nearest to zero: one, five, two, four, three, six, nine, seven,
# Nearest to when: became, after, this, an, saturated, but, dominoes, a,
# Nearest to most: and, are, be, been, in, have, coolest, to,
# Nearest to about: to, zero, this, for, five, have, a, and,
# Nearest to all: for, with, of, the, are, and, living, those,
# Nearest to san: francisco, rez, california, boland, diego, serves, outgrown, jose,
# Nearest to older: families, husband, females, household, versus, median, age, individuals,
# Nearest to heavy: heavier, fuses, wrecks, intense, cantona, therapy, keystrokes, comparatively,
# Nearest to road: roads, railway, wadis, commuter, troubles, rail, capping, crosses,
# Nearest to primarily: loretta, balinese, ets, range, primary, aimed, scandinavians, categories,
# Nearest to animals: animal, prana, synonym, minke, monk, glutamic, veterinary, pixar,
# Nearest to channel: cable, splits, sukhum, corner, presentations, aired, channels, pbs,
# Nearest to account: accounts, kw, regarding, mackie, commentaries, accomplish, kruskal, belshazzar,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8549 0.0309 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8183 0.0297 sec/batch

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from checkpoints/text8.ckpt

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
